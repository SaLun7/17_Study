# %%
fig, axes = plt.subplots(1, 4, figsize = (20, 0))

axes[0].imshow(lenna_image, cmap = 'gray')
axes[0].axis('off')

axes[0].imshow(salted_lenna, cmap = 'gray')
axes[0].axis('off')

axes[0].imshow(pepered_lenna, cmap = 'gray')
axes[0].axis('off')

axes[0].imshow(filtered_lenna, cmap = 'gray')
axes[0].axis('off')

plt.tight_layout()
plt.show()
